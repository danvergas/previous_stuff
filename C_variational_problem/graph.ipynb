# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import cm
t = []
x = []
det = []
df = pd.read_csv('output_0.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
det.append(df['det'].to_numpy())
df = pd.read_csv('output_0.1.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
det.append(df['det'].to_numpy())
df = pd.read_csv('output_1.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
det.append(df['det'].to_numpy())
df = pd.read_csv('output_10.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
det.append(df['det'].to_numpy())
df = pd.read_csv('output_10.5.csv')
t.append(df['t'].to_numpy())
x.append(df['x'].to_numpy())
det.append(df['det'].to_numpy())

# %%
xn = -t[0]**2/2+t[0]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[0], x[0])
#ax.plot(t[0], xn)
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
np.linalg.norm(xn-x[0], 1)
# Out:
# 1.3877787807814457e-17

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[0], det[0])
ax.set_xlabel('t')
ax.set_ylabel("det")
#plt.axis('euql')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[1], x[1])
ax.plot(t[1], x[1])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[1], det[1])
ax.plot(t[1], det[1])
ax.set_xlabel('t')
ax.set_ylabel("det")
#plt.axis('euql')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[2], x[2])
ax.plot(t[2], x[2])
ax.plot(t[2], x[2])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[2], det[2])
ax.plot(t[2], det[2])
ax.plot(t[2], det[2])
ax.set_xlabel('t')
ax.set_ylabel("det")
#plt.axis('euql')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.plot(t[3], x[3])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[3], det[3])
ax.plot(t[3], det[3])
ax.plot(t[3], det[3])
ax.plot(t[3], det[3])
ax.set_xlabel('t')
ax.set_ylabel("det")
#plt.axis('euql')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[4], x[4])
ax.plot(t[4], x[4])
ax.plot(t[4], x[4])
ax.plot(t[4], x[4])
ax.plot(t[4], x[4])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(t[4], det[4])
ax.plot(t[4], det[4])
ax.plot(t[4], det[4])
ax.plot(t[4], det[4])
ax.plot(t[4], det[4])
ax.set_xlabel('t')
ax.set_ylabel("det")
#plt.axis('euql')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
for i in range(5):
    ax.plot(t[i], x[i])
ax.set_xlabel('t')
ax.set_ylabel("x")
#plt.axis('euql')
plt.axis('square')
plt.show()

# %%
a=1
-((840*(70 + 11*a))/(1960 + 777*a + 5*a*a))
# Out:
# -24.814004376367613

# %%
(35*(504 + 125*a))/(1960 + 777*a + 5*a*a)
# Out:
# 8.028811086797958

# %%
A = np.array([[2.19619, -3.27568], [-1.35523, 2.02137]])
cond = np.linalg.cond(A)

# %%
cond
# Out:
# 1681234.0011787403

# %%
